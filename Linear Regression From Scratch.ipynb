# %%
import numpy as np

# X = input (hours studied)
# y = output (marks)
X = np.array([1, 2, 3, 4, 5], dtype=float)
y = np.array([2, 4, 5, 4, 5], dtype=float)

# %%
# Initialize Parameters
w = 0.0   # weight
b = 0.0   # bias

# %%
# Prediction Function
def predict(X, w, b):
    return w * X + b

# %%
# Loss Function (MSE)
def compute_loss(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# %%
# Gradient Calculation
def compute_gradients(X, y, y_pred):
    n = len(X)
    dw = (-2/n) * np.sum(X * (y - y_pred))
    db = (-2/n) * np.sum(y - y_pred)
    return dw, db

# %%
# Training Loop (Gradient Descent)
learning_rate = 0.01
epochs = 1000

for i in range(epochs):
    y_pred = predict(X, w, b)
    
    loss = compute_loss(y, y_pred)
    
    dw, db = compute_gradients(X, y, y_pred)
    
    w -= learning_rate * dw
    b -= learning_rate * db

    if i % 100 == 0:
        print(f"Epoch {i}, Loss: {loss}")
# Out:
# Epoch 0, Loss: 17.2
# Epoch 100, Loss: 0.8098859948340905
# Epoch 200, Loss: 0.6475713164381887
# Epoch 300, Loss: 0.5651207584818807
# Epoch 400, Loss: 0.5232385665908599
# Epoch 500, Loss: 0.5019637803301553
# Epoch 600, Loss: 0.49115688341281166
# Epoch 700, Loss: 0.48566733256370115
# Epoch 800, Loss: 0.4828788199355663
# Epoch 900, Loss: 0.48146234654985554

# %%
print("Final weight:", w)
print("Final bias:", b)

print("Prediction for x=6:", predict(6, w, b))
# Out:
# Final weight: 0.6176946148762643
# Final bias: 2.136116825825789
# Prediction for x=6: 5.842284515083374

# %%
print("Prediction for x=2:", predict(2, w, b))
# Out:
# Prediction for x=2: 3.3715060555783176

# %%
print("Prediction for x=1:", predict(1, w, b))
# Out:
# Prediction for x=1: 2.7538114407020533
